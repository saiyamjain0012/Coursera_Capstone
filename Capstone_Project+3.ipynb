# %% [markdown]
# ## Visualizing the Map and Clusters of the Places

# %%
# importing old libraries (also used in the two first parts)
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from bs4 import BeautifulSoup as bs

# %%
# importing new libraries
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Load the pandas dataframe (created in part 2 of the assignment)

# %%
df_toronto=pd.read_csv("toronto_base.csv")
df_toronto.head(7)
# Out:
#    Unnamed: 0           Borough  \
# 0           0       Scarborough
# 1           1        North York
# 2           2   Central Toronto
# 3           3  Downtown Toronto
# 4           4  Downtown Toronto
# 5           5  Downtown Toronto
# 6           6        North York
#
#                                        Neighbourhood Postcode   Latitude  \
# 0                                             Woburn      M1G  43.770992
# 1                                          Glencairn      M6B  43.709577
# 2                   Deer Park, Rathnelly, South Hill      M4V  43.686412
# 3  CN Tower, King and Spadina, Railway Lands, Sou...      M5V  43.628947
# 4                     Toronto Islands, Union Station      M5J  43.640816
# 5                                            Ryerson      M5B  43.657162
# 6                                       Bedford Park      M5M  43.733283
#
#    Longitude
# 0 -79.216917
# 1 -79.445073
# 2 -79.400049
# 3 -79.394420
# 4 -79.381752
# 5 -79.378937
# 6 -79.419750

# %% [markdown]
# ### Create a map of Toronto

# %%
# for the city Toronto, latitude and longtitude are manually extracted via google search
toronto_latitude = 43.6532; toronto_longitude = -79.3832
map_toronto = folium.Map(location = [toronto_latitude, toronto_longitude], zoom_start = 10.7)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Borough'], df_toronto['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_toronto)  
    

map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Create a new data frame with neighborhoods in Scarborough

# %%
# @hiddel_cell
CLIENT_ID = '3UQAO5E1WY5ITJFJLWPNBOXXKSB13RD5NRJ1CN04YWB4HM3F' # your Foursquare ID
CLIENT_SECRET = 'JUEG0PHBMY3HII1IJR4NPBZRKZVD30PNAQMPVSVXCHOJ50JE' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
scarborough_data = df_toronto[df_toronto['Borough'] == 'Scarborough'].reset_index(drop=True)
scarborough_data.head(7)
# Out:
#    Unnamed: 0      Borough           Neighbourhood Postcode   Latitude  \
# 0           0  Scarborough                  Woburn      M1G  43.770992
# 1          11  Scarborough               Agincourt      M1S  43.794200
# 2          19  Scarborough     Scarborough Village      M1J  43.744734
# 3          23  Scarborough  Morningside, West Hill      M1E  43.763573
# 4          24  Scarborough             Birch Cliff      M1N  43.692657
# 5          27  Scarborough               Cedarbrae      M1H  43.773136
# 6          29  Scarborough   Cliffcrest, Cliffside      M1M  43.716316
#
#    Longitude
# 0 -79.216917
# 1 -79.262029
# 2 -79.239476
# 3 -79.188711
# 4 -79.264848
# 5 -79.239476
# 6 -79.239476

# %% [markdown]
# ### Create a map of Scarborough and its neighbourhoods

# %%
address_scar = 'Scarborough,Toronto'
latitude_scar = 43.773077
longitude_scar = -79.257774
print('The geograpical coordinate of Scarborough are {}, {}.'.format(latitude_scar, longitude_scar))
# Out:
# The geograpical coordinate of Scarborough are 43.773077, -79.257774.

# %%
map_scarb = folium.Map(location=[latitude_scar, longitude_scar], zoom_start=12)

# add markers to map
for lat, lng, label in zip(scarborough_data['Latitude'], scarborough_data['Longitude'], scarborough_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_scarb)  
    
map_scarb
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### k-means to cluster the neighborhoods

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans

scarb_data = scarborough_data.drop(16)
# set number of clusters
kclusters = 5

scarb_grouped_clustering = scarb_grouped.drop('Neighborhood', 1)


# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(scarb_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 
#len(kmeans.labels_)#=16
#scarborough_data.shape
# Out:
# array([0, 2, 0, 1, 1, 1, 1, 3, 1, 1])

# %% [markdown]
# ### Include kmeans.labels_ into the  Scarborough dataframe

# %%
scarb_merged = scarb_data

# add clustering labels
scarb_merged['Cluster Labels'] = kmeans.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
scarb_merged = scarb_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighbourhood')

scarb_merged
# Out:
#     Unnamed: 0      Borough  \
# 0            0  Scarborough
# 1           11  Scarborough
# 2           19  Scarborough
# 3           23  Scarborough
# 4           24  Scarborough
# 5           27  Scarborough
# 6           29  Scarborough
# 7           36  Scarborough
# 8           41  Scarborough
# 9           49  Scarborough
# 10          50  Scarborough
# 11          57  Scarborough
# 12          59  Scarborough
# 13          62  Scarborough
# 14          63  Scarborough
# 15          69  Scarborough
#
#                                         Neighbourhood Postcode   Latitude  \
# 0                                              Woburn      M1G  43.770992
# 1                                           Agincourt      M1S  43.794200
# 2                                 Scarborough Village      M1J  43.744734
# 3                              Morningside, West Hill      M1E  43.763573
# 4                                         Birch Cliff      M1N  43.692657
# 5                                           Cedarbrae      M1H  43.773136
# 6                               Cliffcrest, Cliffside      M1M  43.716316
# 7                           Agincourt North, Milliken      M1V  43.815252
# 8                                   Maryvale, Wexford      M1R  43.750071
# 9                                        Steeles West      M1W  43.799525
# 10  Dorset Park, Scarborough Town Centre, Wexford ...      M1P  43.757410
# 11                    Clairlea, Golden Mile, Oakridge      M1L  43.711112
# 12                                      Tam O'Shanter      M1T  43.781638
# 13             Highland Creek, Rouge Hill, Port Union      M1C  43.784535
# 14                                        Upper Rouge      M1X  43.836125
# 15                                     Rouge, Malvern      M1B  43.806686
#
#     Longitude  Cluster Labels  1st Most Common Venue  2nd Most Common Venue  \
# 0  -79.216917               0            Coffee Shop           Soccer Field
# 1  -79.262029               2         Clothing Store           Skating Rink
# 2  -79.239476               0             Playground      Convenience Store
# 3  -79.188711               1      Electronics Store         Breakfast Spot
# 4  -79.264848               1  General Entertainment           Skating Rink
# 5  -79.239476               1        Thai Restaurant     Athletics & Sports
# 6  -79.239476               1    American Restaurant                  Motel
# 7  -79.284577               3             Playground                   Park
# 8  -79.295849               1                 Bakery             Smoke Shop
# 9  -79.318389               1   Fast Food Restaurant     Chinese Restaurant
# 10 -79.273304               1      Indian Restaurant              Pet Store
# 11 -79.284577               4                 Bakery               Bus Line
# 12 -79.304302               2            Pizza Place        Thai Restaurant
# 13 -79.160497               1          Moving Target                    Bar
# 14 -79.205636               1                    NaN                    NaN
# 15 -79.194353               1   Fast Food Restaurant  Vietnamese Restaurant
#
#         3rd Most Common Venue      4th Most Common Venue  \
# 0           Korean Restaurant      Vietnamese Restaurant
# 1              Breakfast Spot                     Lounge
# 2       Vietnamese Restaurant                Coffee Shop
# 3         Rental Car Location                Pizza Place
# 4                        Café            College Stadium
# 5                      Bakery                       Bank
# 6           Indian Restaurant           Hakka Restaurant
# 7       Vietnamese Restaurant             Clothing Store
# 8              Breakfast Spot  Middle Eastern Restaurant
# 9               Grocery Store                Coffee Shop
# 10  Latin American Restaurant         Chinese Restaurant
# 11               Intersection               Soccer Field
# 12        Fried Chicken Joint         Italian Restaurant
# 13      Vietnamese Restaurant           Hakka Restaurant
# 14                        NaN                        NaN
# 15                Coffee Shop           Hakka Restaurant
#
#     5th Most Common Venue  6th Most Common Venue  7th Most Common Venue  \
# 0           Grocery Store  General Entertainment    Fried Chicken Joint
# 1             Coffee Shop          Grocery Store  General Entertainment
# 2        Hakka Restaurant          Grocery Store  General Entertainment
# 3          Medical Center     Mexican Restaurant  Vietnamese Restaurant
# 4   Vietnamese Restaurant            Coffee Shop       Hakka Restaurant
# 5        Hakka Restaurant    Fried Chicken Joint   Caribbean Restaurant
# 6           Grocery Store  General Entertainment    Fried Chicken Joint
# 7           Grocery Store  General Entertainment    Fried Chicken Joint
# 8   Vietnamese Restaurant        College Stadium          Grocery Store
# 9     Japanese Restaurant         Sandwich Place         Breakfast Spot
# 10  Vietnamese Restaurant                    Bar         Breakfast Spot
# 11   Fast Food Restaurant            Bus Station          Metro Station
# 12   Fast Food Restaurant               Pharmacy           Noodle House
# 13          Grocery Store  General Entertainment    Fried Chicken Joint
# 14                    NaN                    NaN                    NaN
# 15          Grocery Store  General Entertainment    Fried Chicken Joint
#
#     8th Most Common Venue  9th Most Common Venue 10th Most Common Venue
# 0    Fast Food Restaurant      Electronics Store         Discount Store
# 1     Fried Chicken Joint   Fast Food Restaurant      Electronics Store
# 2     Fried Chicken Joint   Fast Food Restaurant      Electronics Store
# 3             Coffee Shop  General Entertainment    Fried Chicken Joint
# 4           Grocery Store    Fried Chicken Joint   Fast Food Restaurant
# 5   Vietnamese Restaurant      Convenience Store          Grocery Store
# 6    Fast Food Restaurant      Electronics Store         Discount Store
# 7    Fast Food Restaurant      Electronics Store         Discount Store
# 8   General Entertainment    Fried Chicken Joint   Fast Food Restaurant
# 9       Electronics Store            Pizza Place               Pharmacy
# 10       Hakka Restaurant          Grocery Store  General Entertainment
# 11        College Stadium          Grocery Store  General Entertainment
# 12     Chinese Restaurant  Vietnamese Restaurant            Coffee Shop
# 13   Fast Food Restaurant      Electronics Store         Discount Store
# 14                    NaN                    NaN                    NaN
# 15      Electronics Store         Discount Store       Department Store

# %% [markdown]
# ### Visualize the clusters in the map

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
map_clusters = folium.Map(location = [latitude_scar, longitude_scar], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(scarb_merged['Latitude'], scarb_merged['Longitude'], scarb_merged['Neighbourhood'], scarb_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Examine each of the five clusters

# %%
scarb_merged.loc[scarb_merged['Cluster Labels'] == 0, scarb_merged.columns[[1] + list(range(5, scarb_merged.shape[1]))]]
# Out:
#        Borough  Longitude  Cluster Labels 1st Most Common Venue  \
# 0  Scarborough -79.216917               0           Coffee Shop
# 2  Scarborough -79.239476               0            Playground
#
#   2nd Most Common Venue  3rd Most Common Venue  4th Most Common Venue  \
# 0          Soccer Field      Korean Restaurant  Vietnamese Restaurant
# 2     Convenience Store  Vietnamese Restaurant            Coffee Shop
#
#   5th Most Common Venue  6th Most Common Venue  7th Most Common Venue  \
# 0         Grocery Store  General Entertainment    Fried Chicken Joint
# 2      Hakka Restaurant          Grocery Store  General Entertainment
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0  Fast Food Restaurant     Electronics Store         Discount Store
# 2   Fried Chicken Joint  Fast Food Restaurant      Electronics Store

# %%
scarb_merged.loc[scarb_merged['Cluster Labels'] == 1, scarb_merged.columns[[1] + list(range(5, scarb_merged.shape[1]))]]
# Out:
#         Borough  Longitude  Cluster Labels  1st Most Common Venue  \
# 3   Scarborough -79.188711               1      Electronics Store
# 4   Scarborough -79.264848               1  General Entertainment
# 5   Scarborough -79.239476               1        Thai Restaurant
# 6   Scarborough -79.239476               1    American Restaurant
# 8   Scarborough -79.295849               1                 Bakery
# 9   Scarborough -79.318389               1   Fast Food Restaurant
# 10  Scarborough -79.273304               1      Indian Restaurant
# 13  Scarborough -79.160497               1          Moving Target
# 14  Scarborough -79.205636               1                    NaN
# 15  Scarborough -79.194353               1   Fast Food Restaurant
#
#     2nd Most Common Venue      3rd Most Common Venue  \
# 3          Breakfast Spot        Rental Car Location
# 4            Skating Rink                       Café
# 5      Athletics & Sports                     Bakery
# 6                   Motel          Indian Restaurant
# 8              Smoke Shop             Breakfast Spot
# 9      Chinese Restaurant              Grocery Store
# 10              Pet Store  Latin American Restaurant
# 13                    Bar      Vietnamese Restaurant
# 14                    NaN                        NaN
# 15  Vietnamese Restaurant                Coffee Shop
#
#         4th Most Common Venue  5th Most Common Venue  6th Most Common Venue  \
# 3                 Pizza Place         Medical Center     Mexican Restaurant
# 4             College Stadium  Vietnamese Restaurant            Coffee Shop
# 5                        Bank       Hakka Restaurant    Fried Chicken Joint
# 6            Hakka Restaurant          Grocery Store  General Entertainment
# 8   Middle Eastern Restaurant  Vietnamese Restaurant        College Stadium
# 9                 Coffee Shop    Japanese Restaurant         Sandwich Place
# 10         Chinese Restaurant  Vietnamese Restaurant                    Bar
# 13           Hakka Restaurant          Grocery Store  General Entertainment
# 14                        NaN                    NaN                    NaN
# 15           Hakka Restaurant          Grocery Store  General Entertainment
#
#     7th Most Common Venue  8th Most Common Venue  9th Most Common Venue  \
# 3   Vietnamese Restaurant            Coffee Shop  General Entertainment
# 4        Hakka Restaurant          Grocery Store    Fried Chicken Joint
# 5    Caribbean Restaurant  Vietnamese Restaurant      Convenience Store
# 6     Fried Chicken Joint   Fast Food Restaurant      Electronics Store
# 8           Grocery Store  General Entertainment    Fried Chicken Joint
# 9          Breakfast Spot      Electronics Store            Pizza Place
# 10         Breakfast Spot       Hakka Restaurant          Grocery Store
# 13    Fried Chicken Joint   Fast Food Restaurant      Electronics Store
# 14                    NaN                    NaN                    NaN
# 15    Fried Chicken Joint      Electronics Store         Discount Store
#
#    10th Most Common Venue
# 3     Fried Chicken Joint
# 4    Fast Food Restaurant
# 5           Grocery Store
# 6          Discount Store
# 8    Fast Food Restaurant
# 9                Pharmacy
# 10  General Entertainment
# 13         Discount Store
# 14                    NaN
# 15       Department Store

# %%
scarb_merged.loc[scarb_merged['Cluster Labels'] == 2, scarb_merged.columns[[1] + list(range(5, scarb_merged.shape[1]))]]
# Out:
#         Borough  Longitude  Cluster Labels 1st Most Common Venue  \
# 1   Scarborough -79.262029               2        Clothing Store
# 12  Scarborough -79.304302               2           Pizza Place
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 1           Skating Rink        Breakfast Spot                Lounge
# 12       Thai Restaurant   Fried Chicken Joint    Italian Restaurant
#
#    5th Most Common Venue 6th Most Common Venue  7th Most Common Venue  \
# 1            Coffee Shop         Grocery Store  General Entertainment
# 12  Fast Food Restaurant              Pharmacy           Noodle House
#
#    8th Most Common Venue  9th Most Common Venue 10th Most Common Venue
# 1    Fried Chicken Joint   Fast Food Restaurant      Electronics Store
# 12    Chinese Restaurant  Vietnamese Restaurant            Coffee Shop

# %%
scarb_merged.loc[scarb_merged['Cluster Labels'] == 3, scarb_merged.columns[[1] + list(range(5, scarb_merged.shape[1]))]]
# Out:
#        Borough  Longitude  Cluster Labels 1st Most Common Venue  \
# 7  Scarborough -79.284577               3            Playground
#
#   2nd Most Common Venue  3rd Most Common Venue 4th Most Common Venue  \
# 7                  Park  Vietnamese Restaurant        Clothing Store
#
#   5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 7         Grocery Store  General Entertainment   Fried Chicken Joint
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 7  Fast Food Restaurant     Electronics Store         Discount Store

# %%
scarb_merged.loc[scarb_merged['Cluster Labels'] == 4, scarb_merged.columns[[1] + list(range(5, scarb_merged.shape[1]))]]
# Out:
#         Borough  Longitude  Cluster Labels 1st Most Common Venue  \
# 11  Scarborough -79.284577               4                Bakery
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 11              Bus Line          Intersection          Soccer Field
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 11  Fast Food Restaurant           Bus Station         Metro Station
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 11       College Stadium         Grocery Store  General Entertainment
